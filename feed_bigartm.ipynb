# %%
import artm

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style("whitegrid", {'axes.grid' : False})

# %%
import numpy as np
import pandas as pd
from sklearn.externals import joblib

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [raw]
# Well, if you have data in UCI format
# (e.g. vocab.my_collection.txt and docword.my_collection.txt files),
# that were put into the same directory with your script or notebook (in our case - with this notebook),
# you can create batches using next code:

# %%
batch_vectorizer = artm.BatchVectorizer(data_path='.',
                                        data_format='bow_uci',
                                        collection_name='rbc',
                                        target_folder='rbc_batches')

# %%
np.random.seed(1)
dictionary = artm.Dictionary('dict')
my_dictionary.gather(data_path='rbc_batches',
                  vocab_file_path='vocab.rbc.txt')
model.initialize(dictionary=my_dictionary)

# %%
my_dictionary.save(dictionary_path='rbc_batches/my_dictionary')

# %%
my_dictionary.load(dictionary_path='rbc_batches/my_dictionary.dict')

# %%
batch_vectorizer.dictionary
# Out:
# artm.Dictionary(name=62d732d9-dc07-4abb-91da-2ef12abd738c, num_entries=689)

# %%
T = 26 # number of topics
topic_names=["Topic_"+(str(i)) for i in range(T-1)]+["bcg"]

model = artm.ARTM(num_topics=T, topic_names=topic_names, num_processors=2,
                  reuse_theta=True, cache_theta=True, dictionary=my_dictionary)

# %%
model.scores.add(artm.TopTokensScore(name='top_tokens_score_mod1', num_tokens=15))

# %%
model.regularizers.add(artm.SmoothSparsePhiRegularizer(tau=1e5, class_ids='text', dictionary='dict', topic_names='bcg'))

# %%
model.num_document_passes = 1
model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=26)

# %%
topic_names_cleared = list(topic_names).remove('bcg')
model.regularizers.add(artm.SmoothSparsePhiRegularizer(tau=-1e5, class_ids='text', dictionary='dict',
                                                       topic_names=topic_names_cleared))

# %%
model.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=15)

# %%
tokens = model.score_tracker['top_tokens_score_mod1'].last_tokens
for topic_name in model.topic_names:
    print (topic_name + ': ')
    for word in tokens[topic_name]:    
        print(word, end = ", ")
    print("\n")
# Out:
# Topic_0:
# турист, банкротство, фонд, выплата, деятельность, проблема, ростуризм, предлагать, получать, случай, туризм, человек, туроператор, направление, который,
#
# Topic_1:
# газпром, объем, европейский, поставка, европа, декабрь, показатель, заявка, рамка, контрактный, млрд, сообщать, прошлое, gazp, ниже,
#
# Topic_2:
# крупный, ведомство, цена, млрд, участник, соглашение, шесть, сумма, срок, свобода, размер, проводить, поддерживать, мочь, конкуренция,
#
# Topic_3:
# система, который, туризм, задача, страна, путевка, работать, бизнес, туроператор, обязательство, деньги, гостиница, направление, самый, греция,
#
# Topic_4:
# догузов, ростуризм, туроператор, глава, турист, должный, путевка, фонд, заявлять, туристический, случай, выплата, пандемия, турпродукт, клиент,
#
# Topic_5:
# который, россия, свой, самый, страна, направление, говорить, бизнес, давать, электронный, поэтому, нужно, многие, президент, высокий,
#
# Topic_6:
# который, человек, россия, инвестиция, мочь, новый, самый, время, директор, технология, сергей, экономика, совет, гендиректор, сделать,
#
# Topic_7:
# продукция, закон, который, импортер, новый, рынок, бизнес, россия, правительство, ситуация, маркировка, законодательство, также, говорить, российский,
#
# Topic_8:
# увеличивать, декабрь, млрд, максимум, сутки, потребитель, мало, данный, российский, цена, газпром, сообщать, поставка, часть, установленный,
#
# Topic_9:
# который, новый, развитие, россия, бизнес, говорить, поэтому, правительство, президент, самый, деньги, также, позволять, бренд, регион,
#
# Topic_10:
# туроператор, турист, около, млрд, случай, банкротство, рубеж, проблема, фонд, рынок, закон, решать, часть, выплата, либо,
#
# Topic_11:
# маркировка, электронный, который, система, должный, бизнес, чтение, информационный, туроператор, продукция, слово, человек, закон, второй, туристический,
#
# Topic_12:
# туроператор, система, человек, работать, туризм, сегодня, отрасль, цена, показатель, деньги, программа, фонд, страна, сумма, качество,
#
# Topic_13:
# российский, производство, отмечать, начинать, россия, который, владелец, добавлять, составлять, январь, регулирование, правительство, слово, продукция, порядок,
#
# Topic_14:
# система, электронный, маркировка, отрасль, туроператор, создавать, который, туристический, продавать, объем, работать, контроль, возврат, обязательство, закон,
#
# Topic_15:
# туроператор, турист, который, ростуризм, получать, ответственность, фонд, случай, туризм, каждый, отдых, защищать, закон, система, оказываться,
#
# Topic_16:
# гендиректор, инвестиция, человек, самый, россия, андрей, интересный, проект, собственный, председатель, сергей, давать, перспектива, каждый, высокий,
#
# Topic_17:
# млрд, турист, туроператор, человек, решать, задача, система, создавать, деньги, цена, каждый, программа, государство, число, качество,
#
# Topic_18:
# развитие, млрд, город, правительство, владивосток, территория, потратить, около, новый, который, экономический, число, слово, рамка, проект,
#
# Topic_19:
# европа, газпром, поставка, цена, свой, представитель, поставлять, сообщать, заявка, слово, природный, превышать, покупатель, называть, заявлять,
#
# Topic_20:
# система, туроператор, туризм, задача, бизнес, сегодня, отрасль, работать, давать, должный, путевка, ответственность, очень, каждый, обязательство,
#
# Topic_21:
# турист, ростуризм, туроператор, фонд, случай, выплата, банкротство, компенсация, ответственность, догузов, клиент, система, крах, позволять, застраховывать,
#
# Topic_22:
# турист, туроператор, фонд, ростуризм, получать, предлагать, который, отправлять, отдых, гарантия, рубеж, туризм, система, должный, выездной,
#
# Topic_23:
# оценивать, зеленый, налог, трлн, цена, становиться, российский, владелец, производство, введение, водород, уровень, очень, сбор, технология,
#
# Topic_24:
# турист, туроператор, туризм, отрасль, человек, который, создавать, массовый, гостиница, выплата, ростуризм, сегодня, задача, направление, программа,
#
# bcg:
# туроператор, турфирма, турист, получать, фонд, случай, глава, который, банкротство, ответственность, отдых, законодательство, млрд, компенсация, крупный,

# %%
T = 12 # number of topics
topic_names=["Topic_"+(str(i)) for i in range(T-1)]+["bcg"]

lda = artm.LDA(num_topics=15, alpha=0.01, beta=0.001,
               num_document_passes=5, dictionary=my_dictionary,
               cache_theta=True)

# %%
lda.fit_offline(batch_vectorizer=batch_vectorizer, num_collection_passes=10)

# %%
lda.sparsity_phi_last_value
lda.sparsity_theta_last_value
# Out:
# 0.0
# 0.0

# %%
lda.perplexity_value
# Out:
# [681.2626953125,
#  416.35003662109375,
#  321.06982421875,
#  241.34381103515625,
#  214.24884033203125,
#  203.34326171875,
#  196.08868408203125,
#  191.6376190185547,
#  189.9319610595703,
#  189.30413818359375]

# %%
top_tokens = lda.get_top_tokens(num_tokens=10)
for i, token_list in enumerate(top_tokens):
    print('Topic #{0}: {1}'.format(i, token_list),"\n")
# Out:
# Topic #0: ['турист', 'фонд', 'туроператор', 'банкротство', 'случай', 'получать', 'ростуризм', 'предлагать', 'выплата', 'система']
#
# Topic #1: ['газпром', 'поставка', 'европа', 'объем', 'цена', 'европейский', 'заявка', 'сообщать', 'свой', 'представитель']
#
# Topic #2: ['крупный', 'ведомство', 'млрд', 'цена', 'участник', 'соглашение', 'сумма', 'мочь', 'срок', 'проводить']
#
# Topic #3: ['который', 'турист', 'туризм', 'система', 'путевка', 'задача', 'каждый', 'туроператор', 'получать', 'гостиница']
#
# Topic #4: ['туроператор', 'ростуризм', 'компенсация', 'догузов', 'случай', 'фонд', 'ответственность', 'глава', 'турист', 'турфирма']
#
# Topic #5: ['турист', 'который', 'туроператор', 'туризм', 'россия', 'самый', 'направление', 'ростуризм', 'давать', 'программа']
#
# Topic #6: ['который', 'человек', 'россия', 'инвестиция', 'гендиректор', 'самый', 'новый', 'андрей', 'технология', 'сергей']
#
# Topic #7: ['продукция', 'закон', 'который', 'импортер', 'рынок', 'новый', 'бизнес', 'россия', 'правительство', 'законодательство']
#
# Topic #8: ['газпром', 'декабрь', 'увеличивать', 'млрд', 'европейский', 'поставка', 'максимум', 'объем', 'потребитель', 'сутки']
#
# Topic #9: ['развитие', 'млрд', 'город', 'правительство', 'владивосток', 'территория', 'новый', 'около', 'потратить', 'который']
#
# Topic #10: ['турист', 'туроператор', 'млрд', 'около', 'фонд', 'банкротство', 'рубеж', 'случай', 'отрасль', 'решать']
#
# Topic #11: ['маркировка', 'ростуризм', 'электронный', 'должный', 'система', 'догузов', 'туроператор', 'который', 'путевка', 'турист']
#
# Topic #12: ['туроператор', 'человек', 'турист', 'отрасль', 'система', 'туризм', 'ростуризм', 'фонд', 'работать', 'сегодня']
#
# Topic #13: ['российский', 'производство', 'оценивать', 'зеленый', 'владелец', 'налог', 'трлн', 'россия', 'становиться', 'цена']
#
# Topic #14: ['туроператор', 'система', 'создавать', 'который', 'отрасль', 'задача', 'электронный', 'защищать', 'работать', 'туристический']

# %%
phi = lda.phi_
theta = lda.get_theta()

# %%
phi
# Out:
#               topic_0   topic_1  topic_2   topic_3   topic_4   topic_5  \
# gazp         0.000002  0.007690  0.00001  0.000002  0.000004  0.000005
# group        0.000004  0.000007  0.00001  0.000423  0.000004  0.001334
# mouzenidis   0.006047  0.000007  0.00001  0.003494  0.000694  0.004839
# travel       0.005257  0.000007  0.00001  0.008163  0.001677  0.003261
# агентство    0.002930  0.007212  0.00001  0.001641  0.000460  0.000903
# ...               ...       ...      ...       ...       ...       ...
# эффективный  0.000004  0.000007  0.00001  0.002355  0.000004  0.002868
# южный        0.003076  0.000007  0.00001  0.000305  0.000320  0.000678
# юрлица       0.006515  0.000007  0.00001  0.000117  0.000159  0.000047
# являться     0.000004  0.000007  0.00001  0.002471  0.000005  0.004021
# январь       0.000002  0.000007  0.00001  0.000002  0.000004  0.000005
#
#               topic_6   topic_7   topic_8   topic_9  topic_10  topic_11  \
# gazp         0.000002  0.000002  0.010203  0.000007  0.000008  0.000002
# group        0.003627  0.006529  0.000011  0.000007  0.001072  0.000002
